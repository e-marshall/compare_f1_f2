# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np 
import xarray as xr

# %%
f1_gslr_ssp585_path = '/Users/emmamarshall/Desktop/facts_work/facts_v1/facts/experiments/ipccar5glaciers.mimicoupling585/output/ipccar5glaciers.mimicoupling585.ar5glaciers.ipccar5.glaciers_globalsl.nc'
f1_lslr_ssp585_path = '/Users/emmamarshall/Desktop/facts_work/facts_v1/facts/experiments/ipccar5glaciers.mimicoupling585/output/ipccar5glaciers.mimicoupling585.ar5glaciers.ipccar5.glaciers_localsl.nc'

f2_gslr_ssp585_path = '/Users/emmamarshall/Desktop/facts_work/facts_v2/ipccar5/data/output/glaciers_gslr.nc'
f2_lslr_ssp585_path = '/Users/emmamarshall/Desktop/facts_work/facts_v2/ipccar5/data/output/glaciers_lslr.nc'

# %%
f1_gslr_585_ds = xr.open_dataset(f1_gslr_ssp585_path)
f1_lslr_585_ds = xr.open_dataset(f1_lslr_ssp585_path)

f2_gslr_585_ds = xr.open_dataset(f2_gslr_ssp585_path)
f2_lslr_585_ds = xr.open_dataset(f2_lslr_ssp585_path)

# %%
xr.testing.assert_allclose(f1_gslr_585_ds['sea_level_change'],
                            f2_gslr_585_ds['sea_level_change'],
)
                           # rtol=1e-5, atol=1e-8)

# %%
xr.testing.assert_allclose(f1_lslr_585_ds['sea_level_change'],
                            f2_lslr_585_ds['sea_level_change'],
)
                           # rtol=1e-5, atol=1e-8)

# %%
f1_gslr_arr = np.squeeze(f1_gslr_585_ds['sea_level_change'].data)
f2_gslr_arr = f2_gslr_585_ds['sea_level_change'].data

# %%
np.testing.assert_allclose(f1_gslr_arr, f2_gslr_arr)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 np.testing.assert_allclose(f1_gslr_arr, f2_gslr_arr)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/facts_work/compare_f1_f2/.venv/lib/python3.12/site-packages/numpy/testing/_private/utils.py:926, in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf, strict, names)
#     921         err_msg += '\n' + '\n'.join(remarks)
#     922         msg = build_err_msg([ox, oy], err_msg,
#     923                             verbose=verbose, header=header,
#     924                             names=names,
#     925                             precision=precision)
# --> 926         raise AssertionError(msg)
#     927 except ValueError:
#     928     import traceback
#
# AssertionError:
# Not equal to tolerance rtol=1e-07, atol=0
#
# ...

# %%
xr.testing.assert_allclose(f1_lslr_585_ds['sea_level_change'],
                            f2_lslr_585_ds['sea_level_change'])

# %%
(f2_gslr_585_ds['sea_level_change'] - f1_gslr_585_ds['sea_level_change']).max()
# Out:
# <xarray.DataArray 'sea_level_change' ()> Size: 8B
# array(1.67883651e-05)

# %%
f1_gslr_585_ds['sea_level_change'].max()
# Out:
# <xarray.DataArray 'sea_level_change' ()> Size: 4B
# array(315.7, dtype=float32)
